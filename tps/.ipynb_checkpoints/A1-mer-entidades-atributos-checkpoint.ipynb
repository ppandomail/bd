# %% [markdown]
# # Actividad 1 - MER: Entidades y Atributos
# ---

# %% [markdown]
# ## Para cada Caso de Estudio identificar

# %% [markdown]
# ### Universo del Discurso

# %% [markdown]
# ### Entidades y atributos

# %% [markdown]
# ### Clasificar los atributos en Simples o Compuestos / Monovalentes o Polivalentes / Identificadores o Descriptores / Obligatorios y No obligatorios

# %% [markdown]
# ### Cardinalidad de cada atributo

# %% [markdown]
# ### Definir el tipo de dato de cada atributo y los dominios de datos definidos por el usuario. Tipos de datos del estándar SQL: CHAR, VARCHAR, INT, FLOAT, REAL, DECIMAL, DATE, TIME, TIMESTAMP, BOOLEAN
