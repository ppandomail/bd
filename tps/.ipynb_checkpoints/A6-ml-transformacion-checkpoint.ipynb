# %% [markdown]
# # Actividad 6 - ML: Fase II
# ---

# %% [markdown]
# ## Para cada Caso de Estudio

# %% [markdown]
# ###  Utilizando el esquema lógico generado en la Actividad 5, realizar las transformaciones necesarias para así obtener el esquema relacional de la base de datos, aplicando los conceptos del Modelo Relacional
