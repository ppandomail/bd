# %% [markdown]
# # Actividad 5 - ML: Fase I
# ---

# %% [markdown]
# ## Para cada Caso de Estudio

# %% [markdown]
# ### Utilizando el esquema conceptual generado en la Actividad 4, reestructurar el mismo para así obtener el esquema lógico de la base de datos, aplicando las transformaciones necesarias en base a la teoría del Modelo Lógico
