# %% [markdown]
# # Actividad 2 - MER: Relaciones
# ---

# %% [markdown]
# ## Para cada Caso de Estudio identificar

# %% [markdown]
# ### Las relaciones y darles un nombre (debe ser un verbo conjugado y en notación snake case)

# %% [markdown]
# ### Las entidades que intervienen en las relaciones

# %% [markdown]
# ### Los atributos que puedan tener las relaciones

# %% [markdown]
# ### Definir el grado de la relación

# %% [markdown]
# ### Definir cardinalidades mínima y máxima y participación para cada entidad que forma parte de cada relación

# %% [markdown]
# ### Definir la conectividad de la relación
