# %% [markdown]
# # Actividad 4 - MER Extendido: Jerarquías y Subconjuntos
# ---

# %% [markdown]
# ## Para cada Caso de Estudio

# %% [markdown]
# ### Identificar y agregar al esquema resultante de la Actividad 3 las jerarquías y los subconjuntos
